# %%
import zipfile
import os

zip_path = 'generated_images.zip'
source_dir = 'generated_images'

with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zf:
    for root, dirs, files in os.walk(source_dir):
        for file in files:
            file_path = os.path.join(root, file)
            zf.write(file_path)

print(f"Запаковано в {zip_path}")
# Out:
# Запаковано в generated_images.zip

# %%
import zipfile

zip_path = 'generated_images.zip'

with zipfile.ZipFile(zip_path, 'r') as zf:
    zf.extractall('.')

print(f"Розпаковано з {zip_path}")
# Out:
# Розпаковано з generated_images.zip
